# %% [markdown]
# # Week 2. Web scraping (continued)

# %% [markdown]
# ## Example: Scraping Craigslist data
# Craiglist provides a wealth of information on apartment rentals and other types of housing (as we saw in the [Boeing and Waddell paper](https://journals.sagepub.com/doi/abs/10.1177/0739456X16664789)). But short of clicking through lots of links, how do we access it?
#
# As with any scraping project, the first step is to get an example web page, and see if we can reverse-engineer the structure.
#
# One option is to parse each detailed post, with information on parking, desired qualities of roommates, etc. But a lot of information is actually in the [list of posts](https://losangeles.craigslist.org/search/lac/hhh).

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://losangeles.craigslist.org/search/lac/hhh'
r = requests.get(url)

# %%
soup = BeautifulSoup(r.content)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <title>
#    central LA housing   - craigslist
#   </title>
#   <script id="ld_breadcrumb_data" type="application/ld+json">
#    {"@context":"https://schema.org","itemListElement":[{"item":{"name":"losangeles.craigslist.org","@id":"https://losangeles.craigslist.org"},"position":1,"@type":"ListItem"},{"item":{"name":"central LA","@id":"https://losangeles.craigslist.org/lac/"},"position":2,"@type":"ListItem"},{"item":{"name":"housing","@id":"https://losangeles.craigslist.org/d/housing/search/lac/hhh"},"position":3,"@type":"ListItem"}],"@type":"BreadcrumbList"}
#   </script>
#   <meta content="" name="description"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible">
#    <link href="https://losangeles.craigslist.org/d/housing/search/lac/hhh" rel="canonical"/>
#    <link href="https://losangeles.craigslist.org/d/housing/search/lac/hhh?s=120" rel="next"/>
#    <meta content="width=device-width,initial-scale=1" name="viewport"/>
#    <link href="//www.craigslist.org/styles/cl.css?v=ebf48c6109c06a8e6dbee442f06f0084" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/search.css?v=fd4f01ec1e3db22cf5a5494aba60e24c" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/leaflet.css?v=d604b055c4c11b9fd29d0c071b394312" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/tocsmaps.css?v=d8743547c59d5ad31d4d7294c7e2f7f2" media="all" rel="stylesheet" type="text/css"/>
#    <!--[if IE]>
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=6bcbe5817e70c9a7f673ff72ba3e56e5">
# <![endif]-->
#    <script type="text/javascript">
#     <!--
# var areaCountry = "US";
# var areaID = "7";
# var areaRegion = "CA";
# var catAbb = "hhh";
# var countOfTotalText = "image {count} of {total}";
# var currencySymbol = "&#x0024;";
# var defaultView = "grid";
# var expiredFavIDs = null;
# var imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"4":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"3":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};
# var lessInfoText = "less info";
# var maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";
# var maxResults = 3000;
# var noImageText = "no image";
# var pID = null;
# var postalLat = null;
# var postalLon = null;
# var purveyorCategories = null;
# var searchDistance = null;
# var sectionAbb = "hhh";
# var sectionBase = "hhh";
# var showInfoText = "show info";
# var showMapTabs = 1;
# var showingBanished = 0;
# var showingFavorites = 0;
# var starHint = "save this post in your favorites list";
# var subarea = "lac";
# var zoomToPosting = null;
# -->
#    </script>
#   </meta>
#  </head>
#  <body class="search has-map">
#   <script type="text/javascript">
#    <!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof window.sectionBase !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(window.sectionBase + ':([^,]+)', 'i')) || {})[1] || window.defaultView;
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# -->
#   </script>
#   <section class="page-container" id="page-top">
#    <div class="bglogo">
#    </div>
#    <div class="tryapp">
#     try the craigslist app »
#     <a class="appstorebtn" href="https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile">
#      Android
#     </a>
#     <a class="appstorebtn" href="https://apps.apple.com/us/app/craigslist/id1336642410">
#      iOS
#     </a>
#    </div>
#    <header class="global-header wide">
#     <a class="header-logo" href="/" name="logoLink">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <form action="/search/lac/hhh" class="breadcrumbs-form" data-action="/search/###/hhh" id="breadcrumbform" method="get">
#       <ul class="breadcrumbs">
#        <li class="crumb area">
#         <span class="no-js">
#          <a href="/">
#           los angeles
#          </a>
#         </span>
#         <select class="js-only" id="areaAbb" name="areaAbb">
#          <option value="losangeles">
#           los angeles
#          </option>
#          <option value="bakersfield">
#           bakersfield
#          </option>
#          <option value="fresno">
#           fresno
#          </option>
#          <option value="hanford">
#           hanford
#          </option>
#          <option value="imperial">
#           imperial co
#          </option>
#          <option value="inlandempire">
#           inland empire
#          </option>
#          <option value="lasvegas">
#           las vegas
#          </option>
#          <option value="orangecounty">
#           orange co
#          </option>
#          <option value="palmsprings">
#           palm springs
#          </option>
#          <option value="sandiego">
#           san diego
#          </option>
#          <option value="slo">
#           san luis obispo
#          </option>
#          <option value="santabarbara">
#           santa barbara
#          </option>
#          <option value="santamaria">
#           santa maria
#          </option>
#          <option value="ventura">
#           ventura
#          </option>
#          <option value="visalia">
#           visalia-tulare
#          </option>
#          <option value="yuma">
#           yuma
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb subarea">
#         <select id="subArea" name="subArea">
#          <option value="">
#           all los angeles
#          </option>
#          <option value="sfv">
#           SF valley
#          </option>
#          <option value="ant">
#           antelope valley
#          </option>
#          <option selected="" value="lac">
#           central LA
#          </option>
#          <option value="lgb">
#           long beach
#          </option>
#          <option value="sgv">
#           san gabriel valley
#          </option>
#          <option value="wst">
#           westside-southbay
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb section">
#         <select id="catAbb" name="catAbb">
#          <option value="ccc">
#           community
#          </option>
#          <option value="eee">
#           events
#          </option>
#          <option value="sss">
#           for sale
#          </option>
#          <option value="ggg">
#           gigs
#          </option>
#          <option selected="" value="hhh">
#           housing
#          </option>
#          <option value="jjj">
#           jobs
#          </option>
#          <option value="rrr">
#           resumes
#          </option>
#          <option value="bbb">
#           services
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb category">
#         <select class="js-only" id="subcatAbb">
#          <option value="hhh">
#           all
#          </option>
#          <option value="apa">
#           apartments / housing for rent
#          </option>
#          <option value="swp">
#           housing swap
#          </option>
#          <option value="off">
#           office &amp; commercial
#          </option>
#          <option value="prk">
#           parking &amp; storage
#          </option>
#          <option value="reb">
#           real estate - by broker
#          </option>
#          <option value="reo">
#           real estate - by owner
#          </option>
#          <option value="roo">
#           rooms &amp; shares
#          </option>
#          <option value="sub">
#           sublets &amp; temporary
#          </option>
#          <option value="vac">
#           vacation rentals
#          </option>
#          <option value="hou">
#           wanted: apts
#          </option>
#          <option value="rew">
#           wanted: real estate
#          </option>
#          <option value="sha">
#           wanted: room/share
#          </option>
#          <option value="sbw">
#           wanted: sublet/temp
#          </option>
#         </select>
#         <span class="no-js">
#          housing
#         </span>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb no-js">
#         <input type="submit" value="go"/>
#        </li>
#       </ul>
#      </form>
#     </nav>
#     <div class="userlinks">
#      <ul class="user-actions">
#       <li class="user post">
#        <a href="https://post.craigslist.org/c/lax">
#         post
#        </a>
#       </li>
#       <li class="user account">
#        <a href="https://accounts.craigslist.org/login/home">
#         account
#        </a>
#       </li>
#      </ul>
#      <ul class="user-favs-discards">
#       <li class="user">
#        <div class="favorites">
#         <a class="favlink" href="#">
#          <span aria-hidden="true" class="icon icon-star fav">
#          </span>
#          <span class="fav-number">
#           0
#          </span>
#          <span class="fav-label">
#           favorites
#          </span>
#         </a>
#        </div>
#       </li>
#       <li class="user discards">
#        <form action="/favorites" class="unfavform js-only" method="GET">
#         <div class="to-banish-page">
#          <input class="unfaves" name="fl" type="hidden"/>
#          <input name="uf" type="hidden" value="1"/>
#          <a class="to-banish-page-link" href="#">
#           <span aria-hidden="true" class="icon icon-trash red">
#           </span>
#           <span class="banished_count">
#            0
#           </span>
#           <span class="discards-label">
#            hidden
#           </span>
#          </a>
#         </div>
#        </form>
#       </li>
#      </ul>
#     </div>
#    </header>
#    <header class="global-header narrow">
#     <a class="header-logo" href="/">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <h1 class="breadcrumbs">
#       central LA            &gt;
#
# housing
#      </h1>
#     </nav>
#     <span class="linklike show-wide-header">
#      ...
#     </span>
#    </header>
#    <form action="/d/housing/search/lac/hhh" class="search-form" id="searchform">
#     <div class="querybox">
#      <div class="form-tab js-only">
#       <span class="search-open" title="hide search">
#        «
#       </span>
#       <span class="search-closed" title="show search">
#        »
#       </span>
#      </div>
#      <input autocapitalize="off" autocomplete="off" autocorrect="off" class="flatinput ui-autocomplete-input" data-autocomplete="search" id="query" name="query" placeholder="search housing" type="text" value=""/>
#      <button class="searchbtn" type="submit">
#       <span aria-hidden="true" class="icon icon-search">
#       </span>
#       <span class="screen-reader-text">
#        press to search craigslist
#       </span>
#      </button>
#      <div class="savealert">
#       <a class="saveme" data-action="save" href="https://accounts.craigslist.org/savesearch/save?URL=https%3A%2F%2Flosangeles%2Ecraigslist%2Eorg%2Fd%2Fhousing%2Fsearch%2Flac%2Fhhh" title="save this search">
#        save search
#       </a>
#      </div>
#     </div>
#     <div class="search-options-container">
#      <h1 class="cattitle">
#       <a class="reset" href="/d/housing/search/lac/hhh" title="clear all search parameters">
#        housing
#       </a>
#      </h1>
#      <div class="search-options-header linklike">
#       <div aria-hidden="true" class="icon icon-toggle-gear">
#       </div>
#       options
#       <span class="options-close">
#        close
#       </span>
#      </div>
#      <input id="excats" name="excats" type="hidden"/>
#      <div class="search-options">
#       <div class="searchgroup categories">
#        <ul class="maincats">
#         <li class="morecats js-only closed">
#          <span class="linklike closed">
#           <span class="plusminus">
#            +
#           </span>
#           show 12 categories
#          </span>
#          <span class="linklike open">
#           <span class="plusminus">
#            –
#           </span>
#           hide 12 categories
#          </span>
#          <span class="count">
#          </span>
#         </li>
#        </ul>
#        <ul class="othercats closed">
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="apa" id="cat_apa" name="cat_id" type="checkbox" value="1"/>
#          <a class="category" href="/d/apartments-housing-for-rent/search/lac/apa">
#           apartments / housing for rent
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="swp" id="cat_swp" name="cat_id" type="checkbox" value="65"/>
#          <a class="category" href="/d/housing-swap/search/lac/swp">
#           housing swap
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="off" id="cat_off" name="cat_id" type="checkbox" value="40"/>
#          <a class="category" href="/d/office-commercial/search/lac/off">
#           office &amp; commercial
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="prk" id="cat_prk" name="cat_id" type="checkbox" value="41"/>
#          <a class="category" href="/d/parking-storage/search/lac/prk">
#           parking &amp; storage
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="rea" id="cat_rea" name="cat_id" type="checkbox" value="143,144"/>
#          <a class="category" href="/d/real-estate/search/lac/rea">
#           real estate
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="roo" id="cat_roo" name="cat_id" type="checkbox" value="18"/>
#          <a class="category" href="/d/rooms-shares/search/lac/roo">
#           rooms &amp; shares
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sub" id="cat_sub" name="cat_id" type="checkbox" value="39"/>
#          <a class="category" href="/d/sublets-temporary/search/lac/sub">
#           sublets &amp; temporary
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="vac" id="cat_vac" name="cat_id" type="checkbox" value="99"/>
#          <a class="category" href="/d/vacation-rentals/search/lac/vac">
#           vacation rentals
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="hou" id="cat_hou" name="cat_id" type="checkbox" value="2"/>
#          <a class="category" href="/d/wanted%3A-apts/search/lac/hou">
#           wanted: apts
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="rew" id="cat_rew" name="cat_id" type="checkbox" value="121"/>
#          <a class="category" href="/d/wanted%3A-real-estate/search/lac/rew">
#           wanted: real estate
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sha" id="cat_sha" name="cat_id" type="checkbox" value="19"/>
#          <a class="category" href="/d/wanted%3A-room-share/search/lac/sha">
#           wanted: room/share
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sbw" id="cat_sbw" name="cat_id" type="checkbox" value="58"/>
#          <a class="category" href="/d/wanted%3A-sublet-temp/search/lac/sbw">
#           wanted: sublet/temp
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <div class="selectall js-only checked">
#           <label>
#            <input checked="checked" class="catcheck selectallcb" type="checkbox"/>
#            <span class="all linklike">
#             select all
#            </span>
#           </label>
#          </div>
#         </li>
#        </ul>
#       </div>
#       <input name="userid" type="hidden" value="">
#        <div class="searchgroup" id="basic-bools">
#         <ul>
#          <li>
#           <label class="srchType">
#            <input class="" name="srchType" type="checkbox" value="T"/>
#            search titles only
#           </label>
#          </li>
#          <li>
#           <label class="hasPic">
#            <input class="autosubmit" name="hasPic" type="checkbox" value="1"/>
#            has image
#           </label>
#          </li>
#          <li>
#           <label class="postedToday">
#            <input class="autosubmit" name="postedToday" type="checkbox" value="1"/>
#            posted today
#           </label>
#          </li>
#          <li>
#           <label class="bundleDuplicates">
#            <input class="autosubmit" name="bundleDuplicates" type="checkbox" value="1"/>
#            bundle duplicates
#           </label>
#          </li>
#         </ul>
#         <ul class="js-only nearbyAreas">
#         </ul>
#        </div>
#        <div class="searchgroup">
#         <span class="searchfieldlabel">
#          miles from zip
#         </span>
#         <input class="flatinput searchInput search_distance" inputmode="numeric" maxlength="5" name="search_distance" placeholder="miles" size="5" value="">
#          <input class="flatinput searchInput postal" name="postal" placeholder="from zip" size="7" type="text" value=""/>
#          <span class="icon icon-locate">
#          </span>
#         </input>
#        </div>
#        <div class="searchgroup minmax price" id="price">
#         <span class="searchfieldlabel">
#          price
#         </span>
#         <input class="flatinput min" name="min_price" placeholder="min" title="whole number, no letters or symbols" type="tel" value=""/>
#         <input class="flatinput max" name="max_price" placeholder="max" title="whole number, no letters or symbols" type="tel" value=""/>
#        </div>
#        <div class="searchgroup bed-bath-selects">
#         <span class="searchfieldlabel">
#          bedrooms
#         </span>
#         <select class="autosubmit" name="min_bedrooms">
#          <option value="">
#           min
#          </option>
#          <option value="0">
#           0
#          </option>
#          <option value="1">
#           1
#          </option>
#          <option value="2">
#           2
#          </option>
#          <option value="3">
#           3
#          </option>
#          <option value="4">
#           4
#          </option>
#          <option value="5">
#           5
#          </option>
#          <option value="6">
#           6
#          </option>
#          <option value="7">
#           7
#          </option>
#          <option value="8">
#           8
#          </option>
#         </select>
#         -
#         <select class="autosubmit" name="max_bedrooms">
#          <option value="">
#           max
#          </option>
#          <option value="0">
#           0
#          </option>
#          <option value="1">
#           1
#          </option>
#          <option value="2">
#           2
#          </option>
#          <option value="3">
#           3
#          </option>
#          <option value="4">
#           4
#          </option>
#          <option value="5">
#           5
#          </option>
#          <option value="6">
#           6
#          </option>
#          <option value="7">
#           7
#          </option>
#          <option value="8">
#           8
#          </option>
#         </select>
#        </div>
#        <div class="searchgroup bed-bath-selects">
#         <span class="searchfieldlabel">
#          bathrooms
#         </span>
#         <select class="autosubmit" name="min_bathrooms">
#          <option value="">
#           min
#          </option>
#          <option value="1">
#           1
#          </option>
#          <option value="2">
#           2
#          </option>
#          <option value="3">
#           3
#          </option>
#          <option value="4">
#           4
#          </option>
#          <option value="5">
#           5
#          </option>
#          <option value="6">
#           6
#          </option>
#          <option value="7">
#           7
#          </option>
#          <option value="8">
#           8
#          </option>
#         </select>
#         -
#         <select class="autosubmit" name="max_bathrooms">
#          <option value="">
#           max
#          </option>
#          <option value="1">
#           1
#          </option>
#          <option value="2">
#           2
#          </option>
#          <option value="3">
#           3
#          </option>
#          <option value="4">
#           4
#          </option>
#          <option value="5">
#           5
#          </option>
#          <option value="6">
#           6
#          </option>
#          <option value="7">
#           7
#          </option>
#          <option value="8">
#           8
#          </option>
#         </select>
#        </div>
#        <div class="searchgroup minmax" id="">
#         <span class="searchfieldlabel">
#          ft
#          <sup>
#           2
#          </sup>
#         </span>
#         <input class="flatinput min" name="minSqft" placeholder="min" title="whole number, no letters or symbols" type="tel" value=""/>
#         <input class="flatinput max" name="maxSqft" placeholder="max" title="whole number, no letters or symbols" type="tel" value=""/>
#        </div>
#        <div class="searchgroup">
#         <span class="searchfieldlabel">
#          availability
#         </span>
#         <select class="autosubmit" name="availabilityMode">
#          <option value="0">
#           all dates
#          </option>
#          <option value="1">
#           within 30 days
#          </option>
#          <option value="2">
#           beyond 30 days
#          </option>
#         </select>
#        </div>
#        <div class="searchgroup search-group-checkbox">
#         <label class="private_room">
#          <input class="autosubmit" name="private_room" type="checkbox" value="1">
#           private room
#          </input>
#         </label>
#         <br/>
#         <label class="pets_cat">
#          <input class="autosubmit" name="pets_cat" type="checkbox" value="1">
#           cats ok
#          </input>
#         </label>
#         <br/>
#         <label class="private_bath">
#          <input class="autosubmit" name="private_bath" type="checkbox" value="1">
#           private bath
#          </input>
#         </label>
#         <br/>
#         <label class="pets_dog">
#          <input class="autosubmit" name="pets_dog" type="checkbox" value="1">
#           dogs ok
#          </input>
#         </label>
#         <br/>
#         <label class="is_furnished">
#          <input class="autosubmit" name="is_furnished" type="checkbox" value="1">
#           furnished
#          </input>
#         </label>
#         <br/>
#         <label class="no_smoking">
#          <input class="autosubmit" name="no_smoking" type="checkbox" value="1">
#           no smoking
#          </input>
#         </label>
#         <br/>
#         <label class="wheelchaccess">
#          <input class="autosubmit" name="wheelchaccess" type="checkbox" value="1">
#           wheelchair access
#          </input>
#         </label>
#         <br/>
#         <label class="ev_charging">
#          <input class="autosubmit" name="ev_charging" type="checkbox" value="1">
#           EV charging
#          </input>
#         </label>
#         <br/>
#         <label class="application_fee">
#          <input class="autosubmit" name="application_fee" type="checkbox" value="1">
#           no application fee
#          </input>
#         </label>
#         <br/>
#         <label class="broker_fee">
#          <input class="autosubmit" name="broker_fee" type="checkbox" value="1">
#           no broker fee
#          </input>
#         </label>
#         <br/>
#        </div>
#        <div class="searchgroup search-group-multi_checkbox">
#         <div class="search-attribute hide-list" data-attr="housing_type">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           housing type
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_1" name="housing_type" type="checkbox" value="1">
#              apartment
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_2" name="housing_type" type="checkbox" value="2">
#              condo
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_3" name="housing_type" type="checkbox" value="3">
#              cottage/cabin
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_4" name="housing_type" type="checkbox" value="4">
#              duplex
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_5" name="housing_type" type="checkbox" value="5">
#              flat
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_6" name="housing_type" type="checkbox" value="6">
#              house
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_7" name="housing_type" type="checkbox" value="7">
#              in-law
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_8" name="housing_type" type="checkbox" value="8">
#              loft
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_9" name="housing_type" type="checkbox" value="9">
#              townhouse
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_10" name="housing_type" type="checkbox" value="10">
#              manufactured
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_11" name="housing_type" type="checkbox" value="11">
#              assisted living
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="housing_type_12" name="housing_type" type="checkbox" value="12">
#              land
#             </input>
#            </label>
#           </li>
#           <li class="selectall js-only">
#            <span class="all">
#             select all
#            </span>
#            <span class="none">
#             deselect all
#            </span>
#           </li>
#          </ul>
#         </div>
#         <div class="search-attribute hide-list" data-attr="laundry">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           laundry
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="laundry_1" name="laundry" type="checkbox" value="1">
#              w/d in unit
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="laundry_4" name="laundry" type="checkbox" value="4">
#              w/d hookups
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="laundry_2" name="laundry" type="checkbox" value="2">
#              laundry in bldg
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="laundry_3" name="laundry" type="checkbox" value="3"/>
#             laundry on site
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="laundry_5" name="laundry" type="checkbox" value="5"/>
#             no laundry on site
#            </label>
#           </li>
#          </ul>
#         </div>
#         <div class="search-attribute hide-list" data-attr="parking">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           parking
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_1" name="parking" type="checkbox" value="1"/>
#             carport
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_2" name="parking" type="checkbox" value="2"/>
#             attached garage
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_3" name="parking" type="checkbox" value="3"/>
#             detached garage
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_4" name="parking" type="checkbox" value="4"/>
#             off-street parking
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_5" name="parking" type="checkbox" value="5"/>
#             street parking
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_6" name="parking" type="checkbox" value="6"/>
#             valet parking
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="parking_7" name="parking" type="checkbox" value="7"/>
#             no parking
#            </label>
#           </li>
#           <li class="selectall js-only">
#            <span class="all">
#             select all
#            </span>
#            <span class="none">
#             deselect all
#            </span>
#           </li>
#          </ul>
#         </div>
#         <div class="search-attribute hide-list" data-attr="rent_period">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           rent period
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="rent_period_1" name="rent_period" type="checkbox" value="1"/>
#             daily
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="rent_period_2" name="rent_period" type="checkbox" value="2"/>
#             weekly
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="rent_period_3" name="rent_period" type="checkbox" value="3"/>
#             monthly
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="rent_period_4" name="rent_period" type="checkbox" value="4"/>
#             yearly
#            </label>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="searchgroup">
#         <div class="searchfieldlabel">
#          open house date
#         </div>
#         <select class="autosubmit" id="sale_date" name="sale_date">
#          <option>
#           all dates
#          </option>
#          <option value="2021-04-15">
#           apr 15 - today
#          </option>
#          <option value="2021-04-16">
#           apr 16 - tomorrow
#          </option>
#          <option value="2021-04-17">
#           apr 17 - saturday
#          </option>
#          <option value="2021-04-18">
#           apr 18 - sunday
#          </option>
#          <option value="2021-04-19">
#           apr 19 - monday
#          </option>
#          <option value="2021-04-20">
#           apr 20 - tuesday
#          </option>
#          <option value="2021-04-21">
#           apr 21 - wednesday
#          </option>
#          <option value="2021-04-22">
#           apr 22 - thursday
#          </option>
#          <option value="2021-04-23">
#           apr 23 - friday
#          </option>
#          <option value="2021-04-24">
#           apr 24 - saturday
#          </option>
#          <option value="2021-04-25">
#           apr 25 - sunday
#          </option>
#          <option value="2021-04-26">
#           apr 26 - monday
#          </option>
#          <option value="2021-04-27">
#           apr 27 - tuesday
#          </option>
#          <option value="2021-04-28">
#           apr 28 - wednesday
#          </option>
#          <option value="2021-04-29">
#           apr 29 - thursday
#          </option>
#          <option value="2021-04-30">
#           apr 30 - friday
#          </option>
#          <option value="2021-05-01">
#           may 1 - saturday
#          </option>
#          <option value="2021-05-02">
#           may 2 - sunday
#          </option>
#          <option value="2021-05-03">
#           may 3 - monday
#          </option>
#          <option value="2021-05-04">
#           may 4 - tuesday
#          </option>
#          <option value="2021-05-05">
#           may 5 - wednesday
#          </option>
#          <option value="2021-05-06">
#           may 6 - thursday
#          </option>
#          <option value="2021-05-07">
#           may 7 - friday
#          </option>
#          <option value="2021-05-08">
#           may 8 - saturday
#          </option>
#          <option value="2021-05-09">
#           may 9 - sunday
#          </option>
#          <option value="2021-05-10">
#           may 10 - monday
#          </option>
#          <option value="2021-05-11">
#           may 11 - tuesday
#          </option>
#          <option value="2021-05-12">
#           may 12 - wednesday
#          </option>
#         </select>
#        </div>
#        <div class="searchgroup resetsearch">
#         <a class="reset linklike" href="/d/housing/search/lac/hhh" title="clear all search parameters">
#          reset
#         </a>
#         <button class="searchlink linklike" type="submit">
#          update search
#         </button>
#        </div>
#        <aside class="tsb">
#         <ul>
#          <li>
#           <a href="https://www.craigslist.org/about/FHA">
#            fair housing
#           </a>
#           <li>
#            <a href="https://www.craigslist.org/about/scams">
#             avoiding scams
#            </a>
#           </li>
#          </li>
#         </ul>
#        </aside>
#       </input>
#      </div>
#     </div>
#     <div class="search-legend">
#      <div class="search-view js-only">
#       <div aria-expanded="false" aria-label="view options" class="dropdown dropdown-icons dropdown-arrows dropdown-view" role="toolbar">
#        <ul class="dropdown-list">
#         <li class="dropdown-item mode sel">
#          <button data-selection="list" id="listview" title="show results in a list">
#           <span class="view-list icon">
#           </span>
#           list
#          </button>
#          <span class="toggle-arrow">
#          </span>
#         </li>
#         <li class="dropdown-item mode">
#          <button data-selection="pic" id="picview" title="show results in a list with thumbnail pictures">
#           <span class="view-thumb icon">
#           </span>
#           thumb
#          </button>
#          <span class="toggle-arrow">
#          </span>
#         </li>
#         <li class="dropdown-item mode">
#          <button data-selection="grid" id="gridview" title="show results side-by-side with larger pictures">
#           <span class="view-gallery icon">
#           </span>
#           gallery
#          </button>
#          <span class="toggle-arrow">
#          </span>
#         </li>
#         <li class="dropdown-item mode">
#          <button data-selection="map" id="mapview" title="show results on a map">
#           <span class="view-map icon">
#           </span>
#           map
#          </button>
#          <span class="toggle-arrow">
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="search-sort">
#       <div aria-expanded="false" aria-label="sort options" class="dropdown dropdown-sort dropdown-arrows" data-default-sort="date" role="toolbar">
#        <ul class="dropdown-list">
#         <li aria-selected="false" class="dropdown-item mode">
#          <a data-selection="upcoming" href="/d/housing/search/lac/hhh?sort=upcoming&amp;" title="show upcoming open houses">
#           upcoming
#           <span class="toggle-arrow">
#           </span>
#          </a>
#         </li>
#         <li aria-selected="true" class="dropdown-item mode sel">
#          <a data-selection="date" href="/d/housing/search/lac/hhh?sort=date&amp;" title="show newest matches first">
#           newest
#           <span class="toggle-arrow">
#           </span>
#          </a>
#         </li>
#         <li aria-selected="false" class="dropdown-item mode">
#          <a data-selection="priceasc" href="/d/housing/search/lac/hhh?sort=priceasc&amp;" title="sort by price, lowest to highest">
#           price ↑
#           <span class="toggle-arrow">
#           </span>
#          </a>
#         </li>
#         <li aria-selected="false" class="dropdown-item mode">
#          <a data-selection="pricedsc" href="/d/housing/search/lac/hhh?sort=pricedsc&amp;" title="sort by price, highest to lowest">
#           price ↓
#           <span class="toggle-arrow">
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="paginator buttongroup firstpage">
#       <span class="resulttotal">
#        <span class="for-map">
#         showing
#         <span class="displaycountShow">
#          ...
#         </span>
#         postings
#         <span class="zoom-out-for-more" style="display: none">
#          -
#          <a href="">
#           zoom out for all
#           <span class="total">
#            3000
#           </span>
#          </a>
#         </span>
#        </span>
#       </span>
#       <span class="buttons">
#        <a class="button first" href="/d/housing/search/lac/hhh" title="first page">
#         &lt;&lt;
#        </a>
#        <span class="button first" title="first page">
#         &lt;&lt;
#        </span>
#        <a class="button prev" href="/d/housing/search/lac/hhh" title="previous page">
#         &lt; prev
#        </a>
#        <span class="button prev" title="previous page">
#         &lt; prev
#        </span>
#        <span class="button pagenum">
#         <span class="range">
#          <span class="rangeFrom">
#           1
#          </span>
#          -
#          <span class="rangeTo">
#           120
#          </span>
#         </span>
#         /
#         <span class="totalcount">
#          3000
#         </span>
#        </span>
#        <a class="button next" href="/d/housing/search/lac/hhh?s=120" title="next page">
#         next &gt;
#        </a>
#        <span class="button next" title="next page">
#         next &gt;
#        </span>
#       </span>
#      </div>
#     </div>
#     <div class="content" id="sortable-results">
#      <section class="favlistsection">
#       <section class="favlistinfo">
#       </section>
#       <section class="banishlistinfo">
#       </section>
#      </section>
#      <div class="open-map-view-button">
#       <span>
#        see in map view
#       </span>
#      </div>
#      <div data-arealat="34.052200" data-arealon="-118.242996" id="mapcontainer">
#       <div id="noresult-overlay">
#       </div>
#       <div id="noresult-text">
#        <span class="message">
#         No mappable items found
#        </span>
#       </div>
#       <div class="loading" id="map">
#        <div class="close-full-screen-map-mode-button">
#         close fullscreen
#        </div>
#       </div>
#      </div>
#      <ul class="rows">
#       <li class="result-row" data-pid="7307235726" data-repost-of="7232125267">
#        <a class="result-image gallery" data-ids="3:00101_krqxgOQKQGjz_0CI0pQ,3:00606_b6BSoxxILr4z_0CI0pQ,3:00x0x_5oxKyb25y4Zz_0CI0pQ,3:00l0l_lWvBK8TyXRlz_0CI0pB,3:00T0T_sZrxeOPZysz_0CI0pQ" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-have-onederful-spring-in/7307235726.html">
#         <span class="result-price">
#          $2,050
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2021-04-15 09:33" title="Thu 15 Apr 09:33:34 AM">
#          Apr 15
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7307235726" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-have-onederful-spring-in/7307235726.html" id="postid_7307235726">
#           Have a ONEderful Spring In A ONE BDRM! Los Feliz Blvd.
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $2,050
#          </span>
#          <span class="housing">
#           1br -
#          </span>
#          <span class="result-hood">
#           (Los Feliz)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#       <li class="result-row" data-pid="7307229658" data-repost-of="7286009444">
#        <a class="result-image gallery" data-ids="3:00M0M_8ahinQkfxGnz_1320MM,3:00e0e_48X8qgSpUJTz_0lM0t2,3:00c0c_39eYUEcSzkHz_0MM132,3:00k0k_icvaFDdiPeaz_0MM132,3:00w0w_5GE6xUkfncwz_0MM132,3:00505_bd2llDqfkgMz_0MM132,3:00L0L_ivcMVZviHScz_0MM132,3:00J0J_2skrIo7snVTz_1320MM,3:00q0q_ep3jXuVSwMDz_0MM132" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7307223971" href="https://losangeles.craigslist.org/lac/sub/d/los-angeles-airbnb-style-apartment/7307223971.html" id="postid_7307223971">
#           Airbnb Style Apartment (Month to Month) Available Soon
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $1,000
#          </span>
#          <span class="housing">
#           1br -
#          </span>
#          <span class="result-hood">
#           (Los Angeles)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#       <li class="result-row" data-pid="7299771774" data-repost-of="6498598472">
#        <a class="result-image gallery" data-ids="3:00A0A_6YzObL83uBDz_0t20CI,3:01212_gujFnM2fU4bz_0CI0t2,3:00R0R_e8HmUciJOmzz_0CI0t2,3:00303_8XBUxday43Pz_0t20CI,3:00M0M_frj9i0jIGZ4z_0t20CI,3:00v0v_a9mAK50kEDdz_0t20CI,3:00x0x_2mxxFJ9jGTBz_0t20CI,3:00X0X_i3HMuWjTmqRz_0t20CI,3:00r0r_ifhLfSCy3h6z_0t20CI,3:00t0t_dFeuBCdJVidz_0t20CI,3:00606_ibEXQhiAcdGz_0t20CI,3:00O0O_24qKtpt5IMEz_0CI0t2,3:00q0q_3avZIdM367Tz_0t20t2,3:00v0v_dwMoYpebVhez_0CI0t2,3:00n0n_axwJrk1dQHGz_0t20CI,3:00j0j_aRv79nPJtt7z_0t20CI,3:00w0w_RuGDmV3IIyz_0CI0t2,3:00k0k_5f7HJn6Bqpdz_0CI0t2,3:00W0W_hc7Onw4I098z_0t20CI" href="https://losangeles.craigslist.org/lac/roo/d/los-angeles-private-room-in-house-gay/7299771774.html">
#         <span class="result-price">
#          $975
#         </span>
#        </a>
#        <div class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2021-04-15 09:11" title="Thu 15 Apr 09:11:57 AM">
#          Apr 15
#         </time>
#         <h3 class="result-heading">
#          <a class="result-title hdrlnk" data-id="7299771774" href="https://losangeles.craigslist.org/lac/roo/d/los-angeles-private-room-in-house-gay/7299771774.html" id="postid_7299771774">
#           Private 🏳️‍🌈💕Room in House Gay 🏳️‍🌈. Friendly  Pleasant H
#          </a>
#         </h3>
#         <span class="result-meta">
#          <span class="result-price">
#           $975
#          </span>
#          <span class="housing">
#           1br -
#          </span>
#          <span class="result-hood">
#           (LA  24 Hour Metro 🚇 Near)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </div>
#       </li>
#      </ul>
#     </div>
#     <div class="search-legend bottom">
#      <div class="search-view">
#       <span class="buttongroup">
#        <a class="backtotop button" href="#page-top">
#         ^ back to top
#        </a>
#       </span>
#      </div>
#      <div class="search-sort">
#       <span class="buttongroup">
#        <a class="backtotop button" href="#page-top">
#         ^ back to top
#        </a>
#       </span>
#      </div>
#      <div class="paginator buttongroup firstpage">
#       <span class="resulttotal">
#        <span class="for-map">
#         showing
#         <span class="displaycountShow">
#          ...
#         </span>
#         postings
#         <span class="zoom-out-for-more" style="display: none">
#          -
#          <a href="">
#           zoom out for all
#           <span class="total">
#            3000
#           </span>
#          </a>
#         </span>
#        </span>
#       </span>
#       <span class="buttons">
#        <a class="button first" href="/d/housing/search/lac/hhh" title="first page">
#         &lt;&lt;
#        </a>
#        <span class="button first" title="first page">
#         &lt;&lt;
#        </span>
#        <a class="button prev" href="/d/housing/search/lac/hhh" title="previous page">
#         &lt; prev
#        </a>
#        <span class="button prev" title="previous page">
#         &lt; prev
#        </span>
#        <span class="button pagenum">
#         <span class="range">
#          <span class="rangeFrom">
#           1
#          </span>
#          -
#          <span class="rangeTo">
#           120
#          </span>
#         </span>
#         /
#         <span class="totalcount">
#          3000
#         </span>
#        </span>
#        <a class="button next" href="/d/housing/search/lac/hhh?s=120" title="next page">
#         next &gt;
#        </a>
#        <span class="button next" title="next page">
#         next &gt;
#        </span>
#       </span>
#      </div>
#     </div>
#     <section class="blurbs">
#     </section>
#     <div id="floater">
#      <img alt="" class="loading" src="//www.craigslist.org/images/animated-spinny.gif"/>
#      <img alt="" class="payload" src="//www.craigslist.org/images/animated-spinny.gif"/>
#     </div>
#    </form>
#    <aside class="tsb">
#     <ul>
#      <li>
#       <a href="https://www.craigslist.org/about/FHA">
#        fair housing
#       </a>
#       <li>
#        <a href="https://www.craigslist.org/about/scams">
#         avoiding scams
#        </a>
#       </li>
#      </li>
#     </ul>
#    </aside>
#    <div class="slidemessage">
#     <span class="fave">
#      <span class="star">
#      </span>
#      favorited
#     </span>
#     <span class="unfave">
#      <span class="star">
#      </span>
#      no longer favorited
#     </span>
#     <span class="hide">
#      <span class="trash">
#      </span>
#      hidden
#     </span>
#     <span class="unhide">
#      <span class="trash">
#      </span>
#      no longer hidden
#     </span>
#    </div>
#    <footer>
#     <ul class="clfooter">
#      <li>
#       © 2021
#       <span class="desktop">
#        craigslist
#       </span>
#       <span class="mobile">
#        CL
#       </span>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/help/">
#        help
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/scams">
#        safety
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://www.craigslist.org/about/privacy.policy">
#        privacy
#       </a>
#       <sup class="neu">
#        new
#       </sup>
#      </li>
#      <li class="desktop">
#       <a href="https://forums.craigslist.org/?forumID=8">
#        feedback
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/terms.of.use">
#        terms
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/">
#        about
#       </a>
#      </li>
#      <li class="fsel desktop linklike" data-mode="mobile">
#       mobile
#      </li>
#      <li class="fsel mobile linklike" data-mode="regular">
#       desktop
#      </li>
#     </ul>
#    </footer>
#   </section>
#   <template id="gallerycarousel">
#    <div class="slider-info">
#    </div>
#    <div class="slider-back arrow">
#     &lt;
#    </div>
#    <div class="slider-forward arrow">
#     &gt;
#    </div>
#   </template>
#   <script>
#    try {
#                     if (
#                         !/\/\/.+\.craigslist\.org\/about\//.test(window.location.href)
#                         &&
#                         (!window.addEventListener || JSON.parse(JSON.stringify('x')) !== 'x')
#                     ) {
#                         throw "unsupported browser";
#                     }
#                 } catch (e) {
#                     function cleanup() {
#                         document.body.innerHTML = '<div id="cl-unsupported-browser" style="margin:1em;font-size:150%;text-align:center;">We have detected you are using a browser that is missing critical features.<br><br>Please visit craigslist from a modern browser.</div>';
#                         document.body.style = "display:block";
#                     }
#
#                     try {
#                         document.body.style = "display:none";
#                     } catch (e) {
#                     }
#                     window.onload = cleanup;
#                     window.clUnsupportedBrowser = true;
#                 }
#   </script>
#   <script src="//www.craigslist.org/js/general-concat.min.js?v=2d91af30d4b934fdeac883a1d566126a" type="text/javascript">
#   </script>
#   <script id="clustertemplate" type="text/template">
#    <li class="posting {visited}" data-pid="{PostingID}">
#         <img src="{ImageThumb}">
#         <div class="housing_bubble_banner">
#             <span class="{hasPrice}price">{currencySymbol}{price}</span>
#             <span class="bedrooms">{BedroomsContent}</span>
#             <span class="postingtitle"><a>{PostingTitle}</a></span>
#             <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                 <span class="banish">
#                     <span class="icon icon-trash" role="button"></span>
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#                 <span class="unbanish">
#                     <span class="icon icon-trash red" role="button"></span>
#                     unhide
#                 </span>
#             </span>
#         </div>
#     </li>
#   </script>
#   <script id="postingtemplate" type="text/template">
#    <div class="viewcontainer pics loading">
#         <div class="backtolist">
#             &laquo; back to posting list
#         </div>
#         <div class="title">
#             <span class="icon icon-star" data-pid="{PostingID}" role="button">
#                 <span class="screen-reader-text">favorite this post</span>
#             </span>
#             <span class="postingtitle">
#                 <a href="{PostingURL}" target="_blank">{PostingTitle}</a>
#             </span>
#             <div>
#                 <span class="{hasPrice}price">{currencySymbol}{price}</span>
#                 <span class="bedrooms">{BedroomsContent}</span>
#                 <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                     <span class="banish">
#                         <span class="icon icon-trash" role="button"></span>
#                         <span class="screen-reader-text">hide this posting</span>
#                     </span>
#                     <span class="unbanish">
#                         <span class="icon icon-trash red" role="button"></span>
#                         <span class="screen-reader-text">unhide</span>
#                         unhide
#                     </span>
#                 </span>
#             </div>
#         </div>
#         <hr style="clear:both">
#         <div class="picscontainer gallery">
#             <span class="slider-back arrow">&lt;</span><span class="slider-info"></span><span class="slider-forward arrow">&gt;</span>
#             <div class="swipe">
#                 <div class="swipe-wrap">
#                     <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 </div>
#             </div>
#         </div>
#         <div class="infocontainer"></div>
#         <hr style="clear:both">
#         <div class="timecontainer"></div>
#         <a class="viewpostinglink" href="{PostingURL}" target="_blank">view posting</a>
#         <div class="contenttoggle">
#             <a class="moreinfo">more info</a>
#             <a class="showpics">show images</a>
#         </div>
#     </div>
#   </script>
#   <script id="popuptemplate" type="text/template">
#    <div id="mapbubble" class="posting">
#         <ul id="clusterbubble"></ul>
#         <div id="postbubble"></div>
#     </div>
#   </script>
#   <script src="//www.craigslist.org/js/leaflet-concat.min.js?v=66cc485807e67440f6b0d8f1fbced8ae" type="text/javascript">
#   </script>
#   <script src="//www.craigslist.org/js/search-concat.min.js?v=d5a723cf2be89b6eaae155dd9ada3c27" type="text/javascript">
#   </script>
#   <script src="//www.craigslist.org/js/postings-concat.min.js?v=dc59a76497f8ac00dc99db926c8fef7a" type="text/javascript">
#   </script>
#  </body>
# </html>

# %% [markdown]
# It looks like each post is in a `<li>` tag. Moreover, note that it's also in a `class` called `result-row`. Structured data like this make it much easier to scrape! The `find_all()` function takes an optional `class_` argument that can filter by class.

# %%
posts = soup.find_all('li', class_= 'result-row')

# Note that there are 120 results, which is the number of posts returned on the Craigslist webpage. A good thing!
print(len(posts))

# Let's look at a sample post
posts[0]
# Out:
# 120
# <li class="result-row" data-pid="7307235726" data-repost-of="7232125267">
# <a class="result-image gallery" data-ids="3:00101_krqxgOQKQGjz_0CI0pQ,3:00606_b6BSoxxILr4z_0CI0pQ,3:00x0x_5oxKyb25y4Zz_0CI0pQ,3:00l0l_lWvBK8TyXRlz_0CI0pB,3:00T0T_sZrxeOPZysz_0CI0pQ" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-have-onederful-spring-in/7307235726.html">
# <span class="result-price">$2,050</span>
# </a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-04-15 09:33" title="Thu 15 Apr 09:33:34 AM">Apr 15</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7307235726" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-have-onederful-spring-in/7307235726.html" id="postid_7307235726">Have a ONEderful Spring In A ONE BDRM! Los Feliz Blvd.</a>
# </h3>
# <span class="result-meta">
# <span class="result-price">$2,050</span>
# <span class="housing">
#                     1br -
#                 </span>
# <span class="result-hood"> (Los Feliz)</span>
# <span class="result-tags">
# <span class="pictag">pic</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>

# %% [markdown]
# It looks like the price and the neighborhood have their own class, within the `span` tag.
# The title and URL look like they are within the `a` tag. The number of bedrooms is a bit more complicated, but it's somewhere in the housing class.
#
# Let's test this out. Note that `find` will get the first occurence. `find_all` will get all of them, and return a list. But in the CraigsList posts, there's only either one occurence or they are all the same, so `find` is easier. (Try it out.)

# %%
print('Price:')
print(posts[0].find('span', class_= 'result-price'))

print('\nNeighborhood:') # \n adds an empty line before
print(posts[0].find('span', class_= 'result-hood'))

print('\nHousing size:')
print(posts[0].find('span', class_= 'housing'))

print('\nTitle:')
print(posts[0].find('a', class_= 'result-title'))

# For all of these results, we can extract just the text
print('\nTitle  (text only):')
print(posts[0].find('a', class_= 'result-title').text)

# except the URL has it's own key
print('\nURL:')
print(posts[0].find('a', class_= 'result-title')['href'])
# Out:
# Price:
# <span class="result-price">$2,050</span>
#
# Neighborhood:
# <span class="result-hood"> (Los Feliz)</span>
#
# Housing size:
# <span class="housing">
#                     1br -
#                 </span>
#
# Title:
# <a class="result-title hdrlnk" data-id="7307235726" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-have-onederful-spring-in/7307235726.html" id="postid_7307235726">Have a ONEderful Spring In A ONE BDRM! Los Feliz Blvd.</a>
#
# Title  (text only):
# Have a ONEderful Spring In A ONE BDRM! Los Feliz Blvd.
#
# URL:
# https://losangeles.craigslist.org/lac/apa/d/los-angeles-have-onederful-spring-in/7307235726.html

# %% [markdown]
# Now we understand the structure of each page. So we are ready to put all of the posts in a dataframe.
#
# `pandas` can create a dataframe from many different data structures. But one of the easiest ways to is to create a list of dictionaries, and then tell `pandas` to convert that into a dataframe. The list is of rows. Within each list, we have a dictionary of columns.

# %%
import pandas as pd

# method one: use a try: except block to skip any posts that cause problems
postList = [] # empty list that we can add to

for post in posts:
    try:
        # temporary variables
        price = post.find('span', class_= 'result-price').text
        neighborhood = post.find('span', class_= 'result-hood').text
        housingsize = post.find('span', class_= 'housing').text
        title = post.find('a', class_= 'result-title').text
        url = post.find('a', class_= 'result-title')['href']

        # now put them in the dictionary, and append to our list
        postList.append({'price': price, 'neighborhood':neighborhood, 
                         'housingsize':housingsize, 'title':title, 'url':url})
    except:
        print('could not parse post')
df = pd.DataFrame(postList)


# method two: explicitly check for missing data 
postList = [] # empty list that we can add to

for post in posts:
    # temporary variables
    if post.find('span', class_= 'result-price') is None:
        price = None
    else:
        price = post.find('span', class_= 'result-price').text
    
    # slightly more efficient way, as we only execute post.find() once
    neighborhood = post.find('span', class_= 'result-hood')
    if neighborhood is not None:
        neighborhood = neighborhood.text 

    housingsize = post.find('span', class_= 'housing')
    if housingsize is not None:
        housingsize = housingsize.text
        
    # these two fields seem to be always present, so no need to check for None
    title = post.find('a', class_= 'result-title').text
    url = post.find('a', class_= 'result-title')['href']

    # now put them in the dictionary, and append to our list
    postList.append({'price': price, 'neighborhood':neighborhood, 
                     'housingsize':housingsize, 'title':title, 'url':url})

df = pd.DataFrame(postList)
# Out:
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post
# could not parse post

# %% [markdown]
# <div class="alert alert-block alert-info">
# [N/A - we fixed the error!]
#
# We probably got an error there. Let's discuss how to fix this to be more robust to missing fields.
# </div>

# %%
print(df)
# Out:
#       price                  neighborhood  \
# 0    $2,050                   (Los Feliz)
# 1    $2,000                 (Los Angeles)
# 2       $58              (West Hollywood)
# 3       $58              (West Hollywood)
# 4    $2,195   (Hollywood /Universal City)
# ..      ...                           ...
# 115  $2,950             (Studio City, CA)
# 116  $1,533            (West Los Angeles)
# 117     $58                   (Hollywood)
# 118  $1,000                 (Los Angeles)
# 119    $975    (LA  24 Hour Metro 🚇 Near)
#
#                                            housingsize  \
# 0        \n                    1br -\n
# 1    \n                    1br -\n                 ...
# 2                                                 None
# 3                                                 None
# 4    \n                    1br -\n                 ...
# ..                                                 ...
# 115      \n                    2br -\n
# 116   \n                    350ft2 -\n
# 117                                               None
# 118      \n                    1br -\n
# 119      \n                    1br -\n
#
#                                                  title  \
# 0    Have a ONEderful Spring In A ONE BDRM! Los Fel...
# 1    BRIGHT LOFT W/BALCONY, WOOD FLOORS, SOARING CE...
# 2                                       Welcome to LA!
# 3                            Comfy Clean Private Rooms
# 4    1+1+LOFT in Universal City/Hollywood | Balcony...
# ..                                                 ...
# 115                  Share this amazing house with me!
# 116                                Refrigerator*, near
# 117               Good Vibes, Tiki Garden, Retro Hotel
# 118  Airbnb Style Apartment (Month to Month) Availa...
# 119  Private 🏳️‍🌈💕Room in House Gay 🏳️‍🌈. Friendly ...
#
#                                                    url
# 0    https://losangeles.craigslist.org/lac/apa/d/lo...
# 1    https://losangeles.craigslist.org/lac/apa/d/lo...
# 2    https://losangeles.craigslist.org/lac/vac/d/lo...
# 3    https://losangeles.craigslist.org/lac/vac/d/lo...
# 4    https://losangeles.craigslist.org/lac/apa/d/lo...
# ..                                                 ...
# 115  https://losangeles.craigslist.org/lac/roo/d/st...
# 116  https://losangeles.craigslist.org/lac/apa/d/lo...
# 117  https://losangeles.craigslist.org/lac/vac/d/lo...
# 118  https://losangeles.craigslist.org/lac/sub/d/lo...
# 119  https://losangeles.craigslist.org/lac/roo/d/lo...
#
# [120 rows x 5 columns]

# %% [markdown]
# So it looks pretty good, except for the `housingsize` field. What's going on here?

# %%
print(df.housingsize)

print('\nThe first entry is {}'.format(df.housingsize.iloc[0]))
# Out:
# 0          \n                    1br -\n
# 1      \n                    1br -\n                 ...
# 2                                                   None
# 3                                                   None
# 4      \n                    1br -\n                 ...
#                              ...
# 115        \n                    2br -\n
# 116     \n                    350ft2 -\n
# 117                                                 None
# 118        \n                    1br -\n
# 119        \n                    1br -\n
# Name: housingsize, Length: 120, dtype: object
#
# The first entry is
#                     1br -

# %% [markdown]
# It looks like there is a lot of whitespace here. And sometimes, the field contains ft2, sometimes br, sometimes neither and sometimes both.
#
# Let's use the `split()` function to split the string by the whitespace.

# %%
print(df.housingsize.str.split())
# Out:
# 0                 [1br, -]
# 1      [1br, -, 670ft2, -]
# 2                     None
# 3                     None
# 4      [1br, -, 950ft2, -]
#               ...
# 115               [2br, -]
# 116            [350ft2, -]
# 117                   None
# 118               [1br, -]
# 119               [1br, -]
# Name: housingsize, Length: 120, dtype: object

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Exercise:</strong> Conceptually, how would you go about creating two new fields in the dataframe—bedrooms and sqft? Write some code if you can, but the most important step is to think through how you'd do it in words.
# </div>

# %%
def extract_sqft(housingsize):
    hlist = housingsize.split()
    sqft = None
    for h in hlist:
        if 'ft2' in h:
            sqft = int(h.replace('ft2',''))
    return sqft

df['sq_ft']=df.housingsize.apply(extract_sqft)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-b1f00ab09874> in <module>
#       7     return sqft
#       8
# ----> 9 df['sq_ft']=df.housingsize.apply(extract_sqft)
#
# ~/opt/anaconda3/envs/UP299/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-10-b1f00ab09874> in extract_sqft(housingsize)
#       1 def extract_sqft(housingsize):
# ----> 2     hlist = housingsize.split()
#       3     sqft = None
#       4     for h in hlist:
#       5         if 'ft2' in h:
#
# AttributeError: 'NoneType' object has no attribute 'split'

# %% [markdown]
# Now let's plot the distribution of price. A box plot would be a good choice here.

# %%
# Oops. What went wrong?
#df.boxplot('price')
df.price.head()
# Out:
# 0    $1,200
# 1    $1,900
# 2    $2,415
# 3    $2,076
# 4    $2,295
# Name: price, dtype: object

# %%
df['price_numeric'] = df.price.str.replace('$','').str.replace(',','').astype(float)
# Out:
# <ipython-input-46-ca911b179bdf>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['price_numeric'] = df.price.str.replace('$','').str.replace(',','').astype(float)

# %%
df.boxplot('price_numeric')

# if you want to plot a subset:
#df[df.price_numeric<3000].boxplot('price_numeric')
# Out:
# <AxesSubplot:>

# %%
# We can also break it out by neighborhood.
# But what's the problem here?
df.boxplot('price_numeric', by='neighborhood')
df.neighborhood.unique()
# Out:
# array([' (East Los Angeles)', ' (Burbank)', ' (West Hollywood, CA)',
#        ' (Mid-Wilshire)', ' (Kool Town)',
#        ' (DTLA | Near Fashion District)', ' (South Gate)',
#        ' (Melrose/The Grove)', ' (Koreatown and Los Angeles)',
#        ' (South L.A.)', ' (West Hollywood)', ' (Glendale)',
#        ' (Los Angeles)', ' (ALL CALIFORNIA)',
#        ' (930 Figuroa Terrace, Los Angeles, CA)', ' (Los Angeles , CA)',
#        ' (947 Adelante Ave, Los Angeles, CA 90042)', ' (Bell Gardens)',
#        ' (DTLA)', ' (Beachwood Canyon)', ' (LOS ANGELES)',
#        ' (Close to The Grove)', ' (HUNTINGTON PARK)', ' (Hollywood)',
#        ' (Hollywood / West Hollywood)', ' (Pasadena)', ' (HOLLYWOOD)',
#        ' (La Puente)', ' (Eastavle)', ' (Echo Park)', ' (West Adams)',
#        ' (HOLLYWOOD / 5658 FRANKLIN AVE)',
#        ' (327 N Boylston St. Los Angeles, CA)', ' (Jefferson Park)',
#        ' (2901 E. Olympic Blvd Los Angeles, CA)', ' (Westlake)'],
#       dtype=object)

# %%
# What about the relationship between prices and the apartment size?
#df.plot('price_numeric', 'price_numeric')
df.plot('sq_ft', 'price_numeric', kind='scatter')
# Out:
# <AxesSubplot:xlabel='sq_ft', ylabel='price_numeric'>

# %% [markdown]
# So now we've created a dataframe that extracts all the posts on the first page!
#
# What next?
# * We only have one page, and it would be useful to get data from the subsequent pages
# * Our neighborhood field is really dirty, so it's hard to do any mapping
# * We don't have any information about parking

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Exercise:</strong> How might you implement one or more of these extensions? Before writing any code, sketch out the principle and sequence of steps that you would follow.
# </div>

# %% [markdown]
# Let's briefly see what it would take to get the information on a specific webpage.
#
# Note that we had the foresight to save the URL in the DataFrame that we created above. Let's take the first one.

# %%
#url = df.iloc[0]
url = 'https://losangeles.craigslist.org/lac/apa/d/los-angeles-bed-for-55/7306204147.html'
r = requests.get(url)
txt = r.text
print(txt)
# Out:
# <!DOCTYPE html>
# <html class="no-js">
# <head>
#
# 	<meta charset="UTF-8">
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge">
# 	<meta name="viewport" content="width=device-width,initial-scale=1">
# 	<meta property="og:site_name" content="craigslist">
# 	<meta name="twitter:card" content="preview">
# 	<meta property="og:title" content="1 Bed. for 55+ - apts/housing for rent - apartment rent">
# 	<meta name="description" content="(https://tsahousing.com/affordable_housing.php?property=1351&amp;amp;name=Casa_Lucerna) make sure to rotate the photos daily, different featured photos. Welcome to Thomas Safran &amp;amp; Associates! Casa...">
# 	<meta property="og:description" content="(https://tsahousing.com/affordable_housing.php?property=1351&amp;amp;name=Casa_Lucerna) make sure to rotate the photos daily, different featured photos. Welcome to Thomas Safran &amp;amp; Associates! Casa...">
# 	<meta property="og:image" content="https://images.craigslist.org/00505_cPcJJn0WGSWz_0oU0jm_600x450.jpg">
# 	<meta property="og:url" content="https://losangeles.craigslist.org/lac/apa/d/los-angeles-bed-for-55/7306204147.html">
# 	<meta property="og:type" content="article">
# 	<meta name="robots" content="noarchive,nofollow,unavailable_after: 20-Apr-21 09:33:09 PDT">
# 	<meta name="geo.position" content="34.024500;-118.156100">
# 	<meta name="geo.placename" content="Los Angeles">
# 	<meta name="geo.region" content="US-CA">
# 	<title>1 Bed. for 55+ - apts/housing for rent - apartment rent</title>
# 	<link rel="canonical" href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-bed-for-55/7306204147.html">
#
# <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/cl.css?v=ebf48c6109c06a8e6dbee442f06f0084"><link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/postings.css?v=537d45cae66646d206e71bf74f071755">    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/leaflet.css?v=d604b055c4c11b9fd29d0c071b394312">
#     <script type="application/ld+json" id="ld_breadcrumb_data" >
#     {"@context":"https://schema.org","itemListElement":[{"item":{"name":"losangeles.craigslist.org","@id":"https://losangeles.craigslist.org"},"position":1,"@type":"ListItem"},{"item":{"name":"central LA","@id":"https://losangeles.craigslist.org/lac/"},"position":2,"@type":"ListItem"},{"item":{"name":"housing","@id":"https://losangeles.craigslist.org/d/housing/search/lac/hhh"},"position":3,"@type":"ListItem"},{"item":{"name":"apartments / housing for rent","@id":"https://losangeles.craigslist.org/d/apartments-housing-for-rent/search/lac/apa"},"position":4,"@type":"ListItem"},{"item":{"name":"1 Bed.  for 55+","@id":"https://losangeles.craigslist.org/lac/apa/d/los-angeles-bed-for-55/7306204147.html"},"position":5,"@type":"ListItem"}],"@type":"BreadcrumbList"}
# </script>
#
#     <script type="application/ld+json" id="ld_posting_data" >
#     {"numberOfBedrooms":"1","longitude":"-118.156100","name":"1 Bed.  for 55+","@context":"http://schema.org","latitude":"34.024500","numberOfBathroomsTotal":1,"address":{"streetAddress":"1025 S. Kern Ave","addressCountry":"US","addressLocality":"Los Angeles","postalCode":"90022","addressRegion":"CA","@type":"PostalAddress"},"@type":"Apartment","smokingAllowed":false}
# </script>
#
# </head>
#
# <body class="posting">
# <script type="text/javascript"><!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof window.sectionBase !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(window.sectionBase + ':([^,]+)', 'i')) || {})[1] || window.defaultView;
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# --></script>
#
#     <section class="page-container">
#         <div class="bglogo"></div>
# <div class="tryapp">
#     try the craigslist app &raquo;
#     <a class="appstorebtn"
#     href="https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile">
#         Android
#     </a>
#     <a class="appstorebtn"
#     href="https://apps.apple.com/us/app/craigslist/id1336642410">
#         iOS
#     </a>
# </div>
# <header class="global-header wide">
#    <a class="header-logo" name="logoLink" href="/">CL</a>
#
#     <nav class="breadcrumbs-container">
#
# <ul class="breadcrumbs">
#         <li class="crumb area">
#             <p>
#                     <a href="/">los angeles</a>
#
#                     <span class="breadcrumb-arrow">&gt;</span>
#             </p>
#         </li>
#
#         <li class="crumb subarea">
#             <p>
#                     <a href="/lac/">central LA</a>
#                     <span class="breadcrumb-arrow">&gt;</span>
#             </p>
#         </li>
#
#         <li class="crumb section">
#             <p>
#                     <a href="/search/lac/hhh">housing</a>
#
#                     <span class="breadcrumb-arrow">&gt;</span>
#             </p>
#         </li>
#
#         <li class="crumb category">
#             <p>
#                 <a href="/search/lac/apa">apartments / housing for rent</a>
#
#             </p>
#         </li>
#
# </ul>
#     </nav>
#
# <div class="userlinks">
#     <ul class="user-actions">
#         <li class="user post">
#             <a href="https://post.craigslist.org/c/lax">post</a>
#         </li>
#         <li class="user account">
#             <a href="https://accounts.craigslist.org/login/home">account</a>
#         </li>
#     </ul>
#     <ul class="user-favs-discards">
#         <li class="user">
#             <div class="favorites">
#                 <a href="#" class="favlink"><span class="icon icon-star fav" aria-hidden="true"></span><span class="fav-number"></span><span class="fav-label"> favorites</span></a>
#             </div>
#         </li>
#         <li class="user discards">
#             <form class="unfavform js-only" method="GET" action="/favorites">
#               <div class="to-banish-page">
#                 <input type="hidden" class="unfaves" name="fl">
#                 <input type="hidden" name="uf" value="1">
#                 <a href="#" class="to-banish-page-link">
#                   <span class="icon icon-trash red" aria-hidden="true"></span>
#                   <span class="banished_count"></span>
#                   <span class="discards-label"> hidden</span>
#                 </a>
#               </div>
#           </form>
#         </li>
#     </ul>
# </div>
#
# </header>
# <header class="global-header narrow">
#    <a class="header-logo" href="/">CL</a>
#     <nav class="breadcrumbs-container">
#
# <h1 class="breadcrumbs">
#
# central LA            &gt;
#
# apartments / housing for rent</h1>
#
#
#     </nav>
#     <span class="linklike show-wide-header">...</span>
# </header>
#         <section class="body">
# <header class="dateReplyBar">
#     <div class="prevnext-sec">
#         <div class="prevnext js-only">
#     <a class="prev">&#9664;  prev </a>
#     <a class="backup" title="back to search">&#9650;</a>
#     <a class="next"> next &#9654; </a>
# </div>
#
#     </div>
#
#     <div class="reply-button-row">
#     <div class="actions-combo">
#     <button role="button" class="reply-button js-only" data-href="/reply/lax/apa/7306204147/__SERVICE_ID__">
#       reply
#     </button>
#
#       <div class="reply-info js-only"></div>
#     <div class="fave-unfave action">
#         <div class="fave" role="button"  title="add to favorites">
#             <div class="icon icon-star" aria-hidden="true"></div>
#             <div class="action-label">favorite</div>
#         </div>
#         <div class="unfave" role="button" title="remove from favorites">
#             <div class="icon icon-star fav" aria-hidden="true"></div>
#             <div class="action-label">favorite</div>
#         </div>
#     </div>
# <div class="banish-unbanish action">
#   <div class="banish" data-url="https://post.craigslist.org/flag" role="button"  title="hide this posting">
#     <div class="icon icon-trash" aria-hidden="true"></div>
#     <div class="action-label">hide</div>
#   </div>
#   <div class="unbanish" data-url="https://post.craigslist.org/flag" role="button"  title="restore this posting">
#     <div class="icon icon-trash red" aria-hidden="true"></div>
#     <div class="action-label">unhide</div>
#   </div>
# </div>
#     <div class="flag-action action">
#         <div class="flag" data-url="https://post.craigslist.org/flag" role="button" title="flag as prohibited / spam / miscategorized" >
#             <div class="flagIcon" aria-hidden="true">
#                 <span class="white-flag">&#9872;</span>
#                 <span class="black-flag">&#9873;</span>
#             </div>
#             <div class="action-label">
#                 flag
#             </div>
#         </div>
#         <div class="unflag">
#             <div class="flagIcon" aria-hidden="true">&#9873;</div>
#             <a class="action-label" href="https://www.craigslist.org/about/help/flags_and_community_moderation" title="thanks for flagging!">
#                 flagged
#             </a>
#         </div>
#     </div>
#     </div>
#
#             <p id="display-date" class="postinginfo reveal">
#                     Posted
#                     <time class="date timeago" datetime="2021-04-13T09:29:09-0700">
#                         2021-04-13 09:29
#                     </time>
#             </p>
#
#             <p class="print-information print-contact">
#                 Contact Information: <span class="print-email"></span> <span class="print-phone"></span>
#             </p>
#             <a href="#" id="printme">print</a>
#
#     </div>
#
# </header>
#
# <h1 class="postingtitle">
#     <span class="postingtitletext">
# <span class="price">$1,200</span> <span class="housing">/ 1br - 600ft<sup>2</sup> - </span><span id="titletextonly">1 Bed.  for 55+</span><small> (East Los Angeles)</small>    </span>
# </h1>
# <section class="userbody">
#     <figure class="iw multiimage">
#     <div class="gallery">
#         <span class="slider-back arrow">&lt;</span>
#         <span class="slider-info">image 1 of 9</span>
#         <span class="slider-forward arrow">&gt;</span>
#
#         <div class="swipe">
#             <div class="swipe-wrap">
#                 <div id="1_image_cPcJJn0WGSWz_0oU0jm" data-imgid="cPcJJn0WGSWz_0oU0jm" class="slide first visible">
#                     <img src="https://images.craigslist.org/00505_cPcJJn0WGSWz_0oU0jm
# --></script>
#
# </figure>
#
#
#     <div class="mapAndAttrs">
# <div class="mapbox">
#     <div id="map" class="viewposting" data-latitude="34.024500" data-longitude="-118.156100" data-accuracy="22"></div>
#     <div class="mapaddress">1025 S. Kern Ave</div>
#
# </div>
#
#     <p class="attrgroup">
#
#
#
#             <span class="shared-line-bubble"><b>1BR</b> / <b>1Ba</b></span>
#
#
#
#
#              <span class="shared-line-bubble"><b>600</b>ft<sup>2</sup></span>
#
#     </p>
#     <p class="attrgroup">
#
#
#
#             <span>flooring: <b>wood</b></span>
#             <br>
#
#
#
#
#             <span>apartment</span>
#             <br>
#
#
#
#
#             <span>laundry on site</span>
#             <br>
#
#
#
#
#             <span>no smoking</span>
#             <br>
#
#
#
#
#             <span>carport</span>
#             <br>
#
#
#
#
#             <span>rent period: <b>monthly</b></span>
#             <br>
#
#     </p>
#     </div>
#
#     <section id="postingbody">
#         <div class="print-information print-qrcode-container">
#             <p class="print-qrcode-label">QR Code Link to This Post</p>
#             <div class="print-qrcode" data-location="https://losangeles.craigslist.org/lac/apa/d/los-angeles-bed-for-55/7306204147.html"></div>
#         </div>
# (https://tsahousing.com/affordable_housing.php?property=1351&amp;name=Casa_Lucerna) make sure to rotate the photos daily, different featured photos. <br>
# <br>
# <br>
# Welcome to Thomas Safran &amp; Associates!<br>
# <br>
# Casa Lucerna is a 75-unit tax credit property located in East Los Angeles, CA for people 55 and over. The property is currently accepting applications for the waiting list. This property accepts Housing Choice (Section 8) and VASH vouchers. <br>
# <br>
# The one bedroom units are newly renovated and include a stove, refrigerator, garbage disposal, heating and air conditioning, and carpeting. The property features on-site management and daily maintenance staff and a newly renovated community room with a billiards table, piano, and computer area.<br>
# <br>
# Residents also enjoy lushly landscaped courtyards and a community garden, a gym, and controlled access covered parking. The on-site staff organizes numerous events including weekly bingo, quilting classes, crafts, movie day, dances, pool parties, and monthly birthday parties.<br>
# <br>
# Our professional team is dedicated to your continued comfort and happiness, and because you have enough on your mind, we respond to all maintenance requests within 48 hours.<br>
# <br>
# https://tsahousing.com/affordable_housing.php?property=1351&amp;name=Casa_Lucerna<br>
# <br>
# Prices valid on select apartment homes and are subject to change.  Thomas Safran &amp; Associates reserves the right to terminate or change the offer at any time. <br>
# <br>
# Thank you,<br>
#     </section>
#
# <ul class="notices">
#             <li>do NOT contact me with unsolicited services or offers</li>
# </ul>
#
#     <div class="postinginfos">
#             <p class="postinginfo">post id: 7306204147</p>
#                 <p class="postinginfo reveal">posted: <time class="date timeago" datetime="2021-04-13T09:29:09-0700">2021-04-13 09:29</time></p>
#
#
#                <p class="postinginfo">
#                    <a href="https://accounts.craigslist.org/eaf?postingID=7306204147&amp;token=U2FsdGVkX180OTc2MTQ5N7I9kEnsSqSK1MW-Nd6b4BjVrIUkgiiPCSnR9EA1LNdt" class="email-friend">email to friend</a>
#                </p>
#         <p class="postinginfo">
#               <a class="bestof-link" href="https://post.craigslist.org/flag" title="nominate for best-of-CL">
#                 <span class="bestof-icon">&hearts; </span><span class="bestof-text">best of</span>
#               </a> <sup>[<a href="https://www.craigslist.org/about/best-of-craigslist">?</a>]</sup>
#         </p>
#
#     </div>
#
#     <div class="print-information print-pics"></div>
#
# </section>
#
# <div class="psa-box">
# </div>
#
# <div class="avoid-scams">
# <aside class="tsb">
#     Please flag
#     <a href="https://www.craigslist.org/about/FHA">discriminatory housing ads</a>
# </aside>
#
# <aside class="tsb">
#     <a href="https://www.craigslist.org/about/scams">Avoid scams, deal locally!</a>
#
#     <em>DO NOT wire funds (e.g. Western Union)</em>, or buy/rent sight unseen
# </aside>
# </div>
#
#         </section>
# <footer>
#     <ul class="clfooter">
#         <li>&copy; 2021 <span class="desktop">craigslist</span><span class="mobile">CL</span></li>
#         <li><a href="https://www.craigslist.org/about/help/">help</a></li>
#         <li><a href="https://www.craigslist.org/about/scams">safety</a></li>
#         <li class="desktop"><a href="https://www.craigslist.org/about/privacy.policy">privacy</a><sup class="neu">new</sup></li>
#         <li class="desktop"><a href="https://forums.craigslist.org/?forumID=8">feedback</a></li>
#         <li><a href="https://www.craigslist.org/about/terms.of.use">terms</a></li>
#         <li><a href="https://www.craigslist.org/about/">about</a></li>
#         <li class="fsel desktop linklike" data-mode="mobile">mobile</li>
#         <li class="fsel mobile linklike" data-mode="regular">desktop</li>
#     </ul>
# </footer>
#     </section>
#
#
#         <script type="text/javascript"><!--
# var countOfTotalText = "image {count} of {total}";
# var imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"4":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"3":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};
# var maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";
# var pID = 7306204147;
# var repost_of = 7285745276;
# --></script>
#
#
#                 <script>
#                 try {
#                     if (
#                         !/\/\/.+\.craigslist\.org\/about\//.test(window.location.href)
#                         &&
#                         (!window.addEventListener || JSON.parse(JSON.stringify('x')) !== 'x')
#                     ) {
#                         throw "unsupported browser";
#                     }
#                 } catch (e) {
#                     function cleanup() {
#                         document.body.innerHTML = '<div id="cl-unsupported-browser" style="margin:1em;font-size:150%;text-align:center;">We have detected you are using a browser that is missing critical features.<br><br>Please visit craigslist from a modern browser.</div>';
#                         document.body.style = "display:block";
#                     }
#
#                     try {
#                         document.body.style = "display:none";
#                     } catch (e) {
#                     }
#                     window.onload = cleanup;
#                     window.clUnsupportedBrowser = true;
#                 }
#                 </script>
#             <script src="//www.craigslist.org/js/general-concat.min.js?v=2d91af30d4b934fdeac883a1d566126a" type="text/javascript" ></script>
#
#     <script src="//www.craigslist.org/js/leaflet-concat.min.js?v=66cc485807e67440f6b0d8f1fbced8ae" type="text/javascript" ></script>
#
# <script src="//www.craigslist.org/js/postings-concat.min.js?v=dc59a76497f8ac00dc99db926c8fef7a" type="text/javascript" ></script>
# </body>
# </html>

# %% [markdown]
# We have a couple of strategies here. First, we could skip trying to parse the page with `BeautifulSoup`, and just see if particular bits of text are present.
#
# For example, what transportation modes does the post emphasize? Do they mention Section 8 vouchers? Some of this might be exploratory—we can see what type of language is included, and then parse in a more structured way (e.g. distinguishing between "No Section 8" and "Section 8 welcome").

# %%
txt = txt.lower()
if 'freeway' in txt:
    print('This post mentions freeways')
if 'transit' in txt or 'train' in txt or 'bus' in txt:
        print('This post mentions transit')
if 'section 8' in txt:
        print('This post mentions Section 8')
# Out:
# This post mentions Section 8

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Exercise:</strong> Write a function that takes a URL as its argument, and returns 3 boolean values for whether a post mentions freeways, transit, and Section 8. Make sure that it is not case-sensitive!
# </div>

# %% [markdown]
# Most of the post is free-form text. So there's not going to be much value added by `BeautifulSoup`.
#
# The exception is the geographic coordinates, which look like they are in a `div` tag and a `viewposting` class.

# %%
soup = BeautifulSoup(r.content)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="craigslist" property="og:site_name"/>
#   <meta content="preview" name="twitter:card"/>
#   <meta content="1 Bed. for 55+ - apts/housing for rent - apartment rent" property="og:title"/>
#   <meta content="(https://tsahousing.com/affordable_housing.php?property=1351&amp;amp;name=Casa_Lucerna) make sure to rotate the photos daily, different featured photos. Welcome to Thomas Safran &amp;amp; Associates! Casa..." name="description"/>
#   <meta content="(https://tsahousing.com/affordable_housing.php?property=1351&amp;amp;name=Casa_Lucerna) make sure to rotate the photos daily, different featured photos. Welcome to Thomas Safran &amp;amp; Associates! Casa..." property="og:description"/>
#   <meta content="https://images.craigslist.org/00505_cPcJJn0WGSWz_0oU0jm_600x450.jpg" property="og:image"/>
#   <meta content="https://losangeles.craigslist.org/lac/apa/d/los-angeles-bed-for-55/7306204147.html" property="og:url"/>
#   <meta content="article" property="og:type"/>
#   <meta content="noarchive,nofollow,unavailable_after: 20-Apr-21 09:33:09 PDT" name="robots"/>
#   <meta content="34.024500;-118.156100" name="geo.position"/>
#   <meta content="Los Angeles" name="geo.placename"/>
#   <meta content="US-CA" name="geo.region"/>
#   <title>
#    1 Bed. for 55+ - apts/housing for rent - apartment rent
#   </title>
#   <link href="https://losangeles.craigslist.org/lac/apa/d/los-angeles-bed-for-55/7306204147.html" rel="canonical"/>
#   <link href="//www.craigslist.org/styles/cl.css?v=ebf48c6109c06a8e6dbee442f06f0084" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//www.craigslist.org/styles/postings.css?v=537d45cae66646d206e71bf74f071755" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//www.craigslist.org/styles/leaflet.css?v=d604b055c4c11b9fd29d0c071b394312" media="all" rel="stylesheet" type="text/css"/>
#   <script id="ld_breadcrumb_data" type="application/ld+json">
#    {"@context":"https://schema.org","itemListElement":[{"item":{"name":"losangeles.craigslist.org","@id":"https://losangeles.craigslist.org"},"position":1,"@type":"ListItem"},{"item":{"name":"central LA","@id":"https://losangeles.craigslist.org/lac/"},"position":2,"@type":"ListItem"},{"item":{"name":"housing","@id":"https://losangeles.craigslist.org/d/housing/search/lac/hhh"},"position":3,"@type":"ListItem"},{"item":{"name":"apartments / housing for rent","@id":"https://losangeles.craigslist.org/d/apartments-housing-for-rent/search/lac/apa"},"position":4,"@type":"ListItem"},{"item":{"name":"1 Bed.  for 55+","@id":"https://losangeles.craigslist.org/lac/apa/d/los-angeles-bed-for-55/7306204147.html"},"position":5,"@type":"ListItem"}],"@type":"BreadcrumbList"}
#   </script>
#   <script id="ld_posting_data" type="application/ld+json">
#    {"numberOfBedrooms":"1","longitude":"-118.156100","name":"1 Bed.  for 55+","@context":"http://schema.org","latitude":"34.024500","numberOfBathroomsTotal":1,"address":{"streetAddress":"1025 S. Kern Ave","addressCountry":"US","addressLocality":"Los Angeles","postalCode":"90022","addressRegion":"CA","@type":"PostalAddress"},"@type":"Apartment","smokingAllowed":false}
#   </script>
#  </head>
#  <body class="posting">
#   <script type="text/javascript">
#    <!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof window.sectionBase !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(window.sectionBase + ':([^,]+)', 'i')) || {})[1] || window.defaultView;
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# -->
#   </script>
#   <section class="page-container">
#    <div class="bglogo">
#    </div>
#    <div class="tryapp">
#     try the craigslist app »
#     <a class="appstorebtn" href="https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile">
#      Android
#     </a>
#     <a class="appstorebtn" href="https://apps.apple.com/us/app/craigslist/id1336642410">
#      iOS
#     </a>
#    </div>
#    <header class="global-header wide">
#     <a class="header-logo" href="/" name="logoLink">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <ul class="breadcrumbs">
#       <li class="crumb area">
#        <p>
#         <a href="/">
#          los angeles
#         </a>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </p>
#       </li>
#       <li class="crumb subarea">
#        <p>
#         <a href="/lac/">
#          central LA
#         </a>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </p>
#       </li>
#       <li class="crumb section">
#        <p>
#         <a href="/search/lac/hhh">
#          housing
#         </a>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </p>
#       </li>
#       <li class="crumb category">
#        <p>
#         <a href="/search/lac/apa">
#          apartments / housing for rent
#         </a>
#        </p>
#       </li>
#      </ul>
#     </nav>
#     <div class="userlinks">
#      <ul class="user-actions">
#       <li class="user post">
#        <a href="https://post.craigslist.org/c/lax">
#         post
#        </a>
#       </li>
#       <li class="user account">
#        <a href="https://accounts.craigslist.org/login/home">
#         account
#        </a>
#       </li>
#      </ul>
#      <ul class="user-favs-discards">
#       <li class="user">
#        <div class="favorites">
#         <a class="favlink" href="#">
#          <span aria-hidden="true" class="icon icon-star fav">
#          </span>
#          <span class="fav-number">
#          </span>
#          <span class="fav-label">
#           favorites
#          </span>
#         </a>
#        </div>
#       </li>
#       <li class="user discards">
#        <form action="/favorites" class="unfavform js-only" method="GET">
#         <div class="to-banish-page">
#          <input class="unfaves" name="fl" type="hidden"/>
#          <input name="uf" type="hidden" value="1"/>
#          <a class="to-banish-page-link" href="#">
#           <span aria-hidden="true" class="icon icon-trash red">
#           </span>
#           <span class="banished_count">
#           </span>
#           <span class="discards-label">
#            hidden
#           </span>
#          </a>
#         </div>
#        </form>
#       </li>
#      </ul>
#     </div>
#    </header>
#    <header class="global-header narrow">
#     <a class="header-logo" href="/">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <h1 class="breadcrumbs">
#       central LA            &gt;
#
# apartments / housing for rent
#      </h1>
#     </nav>
#     <span class="linklike show-wide-header">
#      ...
#     </span>
#    </header>
#    <section class="body">
#     <header class="dateReplyBar">
#      <div class="prevnext-sec">
#       <div class="prevnext js-only">
#        <a class="prev">
#         ◀  prev
#        </a>
#        <a class="backup" title="back to search">
#         ▲
#        </a>
#        <a class="next">
#         next ▶
#        </a>
#       </div>
#      </div>
#      <div class="reply-button-row">
#       <div class="actions-combo">
#        <button class="reply-button js-only" data-href="/reply/lax/apa/7306204147/__SERVICE_ID__" role="button">
#         reply
#        </button>
#        <div class="reply-info js-only">
#        </div>
#        <div class="fave-unfave action">
#         <div class="fave" role="button" title="add to favorites">
#          <div aria-hidden="true" class="icon icon-star">
#          </div>
#          <div class="action-label">
#           favorite
#          </div>
#         </div>
#         <div class="unfave" role="button" title="remove from favorites">
#          <div aria-hidden="true" class="icon icon-star fav">
#          </div>
#          <div class="action-label">
#           favorite
#          </div>
#         </div>
#        </div>
#        <div class="banish-unbanish action">
#         <div class="banish" data-url="https://post.craigslist.org/flag" role="button" title="hide this posting">
#          <div aria-hidden="true" class="icon icon-trash">
#          </div>
#          <div class="action-label">
#           hide
#          </div>
#         </div>
#         <div class="unbanish" data-url="https://post.craigslist.org/flag" role="button" title="restore this posting">
#          <div aria-hidden="true" class="icon icon-trash red">
#          </div>
#          <div class="action-label">
#           unhide
#          </div>
#         </div>
#        </div>
#        <div class="flag-action action">
#         <div class="flag" data-url="https://post.craigslist.org/flag" role="button" title="flag as prohibited / spam / miscategorized">
#          <div aria-hidden="true" class="flagIcon">
#           <span class="white-flag">
#            ⚐
#           </span>
#           <span class="black-flag">
#            ⚑
#           </span>
#          </div>
#          <div class="action-label">
#           flag
#          </div>
#         </div>
#         <div class="unflag">
#          <div aria-hidden="true" class="flagIcon">
#           ⚑
#          </div>
#          <a class="action-label" href="https://www.craigslist.org/about/help/flags_and_community_moderation" title="thanks for flagging!">
#           flagged
#          </a>
#         </div>
#        </div>
#       </div>
#       <p class="postinginfo reveal" id="display-date">
#        Posted
#        <time class="date timeago" datetime="2021-04-13T09:29:09-0700">
#         2021-04-13 09:29
#        </time>
#       </p>
#       <p class="print-information print-contact">
#        Contact Information:
#        <span class="print-email">
#        </span>
#        <span class="print-phone">
#        </span>
#       </p>
#       <a href="#" id="printme">
#        print
#       </a>
#      </div>
#     </header>
#     <h1 class="postingtitle">
#      <span class="postingtitletext">
#       <span class="price">
#        $1,200
#       </span>
#       <span class="housing">
#        / 1br - 600ft
#        <sup>
#         2
#        </sup>
#        -
#       </span>
#       <span id="titletextonly">
#        1 Bed.  for 55+
#       </span>
#       <small>
#        (East Los Angeles)
#       </small>
#      </span>
#     </h1>
#     <section class="userbody">
#      <figure class="iw multiimage">
#       <div class="gallery">
#        <span class="slider-back arrow">
#         &lt;
#        </span>
#        <span class="slider-info">
#         image 1 of 9
#        </span>
#        <span class="slider-forward arrow">
#         &gt;
#        </span>
#        <div class="swipe">
#         <div class="swipe-wrap">
#          <div class="slide first visible" data-imgid="cPcJJn0WGSWz_0oU0jm" id="1_image_cPcJJn0WGSWz_0oU0jm">
#           <img alt="1" src="https://images.craigslist.org/00505_cPcJJn0WGSWz_0oU0jm
_loSmB7C3GLqz_0iD0cq"},{"shortid":"e447HsmaPLbz_0iD0cq","url":"https://images.craigslist.org/00n0n_e447HsmaPLbz_0iD0cq_600x450.jpg","thumb":"https://images.craigslist.org/00n0n_e447HsmaPLbz_0iD0cq_50x50c.jpg","imgid":"3:00n0n_e447HsmaPLbz_0iD0cq"},{"shortid":"bws84nStJZHz_0iD0cq","url":"https://images.craigslist.org/00Z0Z_bws84nStJZHz_0iD0cq_600x450.jpg","thumb":"https://images.craigslist.org/00Z0Z_bws84nStJZHz_0iD0cq_50x50c.jpg","imgid":"3:00Z0Z_bws84nStJZHz_0iD0cq"},{"shortid":"fxOvknO8yzZz_0t20jm","url":"https://images.craigslist.org/00l0l_fxOvknO8yzZz_0t20jm_600x450.jpg","thumb":"https://images.craigslist.org/00l0l_fxOvknO8yzZz_0t20jm_50x50c.jpg","imgid":"3:00l0l_fxOvknO8yzZz_0t20jm"}];
# -->
#       </script>
#      </figure>
#      <div class="mapAndAttrs">
#       <div class="mapbox">
#        <div class="viewposting" data-accuracy="22" data-latitude="34.024500" data-longitude="-118.156100" id="map">
#        </div>
#        <div class="mapaddress">
#         1025 S. Kern Ave
#        </div>
#       </div>
#       <p class="attrgroup">
#        <span class="shared-line-bubble">
#         <b>
#          1BR
#         </b>
#         /
#         <b>
#          1Ba
#         </b>
#        </span>
#        <span class="shared-line-bubble">
#         <b>
#          600
#         </b>
#         ft
#         <sup>
#          2
#         </sup>
#        </span>
#       </p>
#       <p class="attrgroup">
#        <span>
#         flooring:
#         <b>
#          wood
#         </b>
#        </span>
#        <br/>
#        <span>
#         apartment
#        </span>
#        <br/>
#        <span>
#         laundry on site
#        </span>
#        <br/>
#        <span>
#         no smoking
#        </span>
#        <br/>
#        <span>
#         carport
#        </span>
#        <br/>
#        <span>
#         rent period:
#         <b>
#          monthly
#         </b>
#        </span>
#        <br/>
#       </p>
#      </div>
#      <section id="postingbody">
#       <div class="print-information print-qrcode-container">
#        <p class="print-qrcode-label">
#         QR Code Link to This Post
#        </p>
#        <div class="print-qrcode" data-location="https://losangeles.craigslist.org/lac/apa/d/los-angeles-bed-for-55/7306204147.html">
#        </div>
#       </div>
#       (https://tsahousing.com/affordable_housing.php?property=1351&amp;name=Casa_Lucerna) make sure to rotate the photos daily, different featured photos.
#       <br/>
#       <br/>
#       <br/>
#       Welcome to Thomas Safran &amp; Associates!
#       <br/>
#       <br/>
#       Casa Lucerna is a 75-unit tax credit property located in East Los Angeles, CA for people 55 and over. The property is currently accepting applications for the waiting list. This property accepts Housing Choice (Section 8) and VASH vouchers.
#       <br/>
#       <br/>
#       The one bedroom units are newly renovated and include a stove, refrigerator, garbage disposal, heating and air conditioning, and carpeting. The property features on-site management and daily maintenance staff and a newly renovated community room with a billiards table, piano, and computer area.
#       <br/>
#       <br/>
#       Residents also enjoy lushly landscaped courtyards and a community garden, a gym, and controlled access covered parking. The on-site staff organizes numerous events including weekly bingo, quilting classes, crafts, movie day, dances, pool parties, and monthly birthday parties.
#       <br/>
#       <br/>
#       Our professional team is dedicated to your continued comfort and happiness, and because you have enough on your mind, we respond to all maintenance requests within 48 hours.
#       <br/>
#       <br/>
#       https://tsahousing.com/affordable_housing.php?property=1351&amp;name=Casa_Lucerna
#       <br/>
#       <br/>
#       Prices valid on select apartment homes and are subject to change.  Thomas Safran &amp; Associates reserves the right to terminate or change the offer at any time.
#       <br/>
#       <br/>
#       Thank you,
#       <br/>
#      </section>
#      <ul class="notices">
#       <li>
#        do NOT contact me with unsolicited services or offers
#       </li>
#      </ul>
#      <div class="postinginfos">
#       <p class="postinginfo">
#        post id: 7306204147
#       </p>
#       <p class="postinginfo reveal">
#        posted:
#        <time class="date timeago" datetime="2021-04-13T09:29:09-0700">
#         2021-04-13 09:29
#        </time>
#       </p>
#       <p class="postinginfo">
#        <a class="email-friend" href="https://accounts.craigslist.org/eaf?postingID=7306204147&amp;token=U2FsdGVkX180OTc2MTQ5N7I9kEnsSqSK1MW-Nd6b4BjVrIUkgiiPCSnR9EA1LNdt">
#         email to friend
#        </a>
#       </p>
#       <p class="postinginfo">
#        <a class="bestof-link" href="https://post.craigslist.org/flag" title="nominate for best-of-CL">
#         <span class="bestof-icon">
#          ♥
#         </span>
#         <span class="bestof-text">
#          best of
#         </span>
#        </a>
#        <sup>
#         [
#         <a href="https://www.craigslist.org/about/best-of-craigslist">
#          ?
#         </a>
#         ]
#        </sup>
#       </p>
#      </div>
#      <div class="print-information print-pics">
#      </div>
#     </section>
#     <div class="psa-box">
#     </div>
#     <div class="avoid-scams">
#      <aside class="tsb">
#       Please flag
#       <a href="https://www.craigslist.org/about/FHA">
#        discriminatory housing ads
#       </a>
#      </aside>
#      <aside class="tsb">
#       <a href="https://www.craigslist.org/about/scams">
#        Avoid scams, deal locally!
#       </a>
#       <em>
#        DO NOT wire funds (e.g. Western Union)
#       </em>
#       , or buy/rent sight unseen
#      </aside>
#     </div>
#    </section>
#    <footer>
#     <ul class="clfooter">
#      <li>
#       © 2021
#       <span class="desktop">
#        craigslist
#       </span>
#       <span class="mobile">
#        CL
#       </span>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/help/">
#        help
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/scams">
#        safety
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://www.craigslist.org/about/privacy.policy">
#        privacy
#       </a>
#       <sup class="neu">
#        new
#       </sup>
#      </li>
#      <li class="desktop">
#       <a href="https://forums.craigslist.org/?forumID=8">
#        feedback
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/terms.of.use">
#        terms
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/">
#        about
#       </a>
#      </li>
#      <li class="fsel desktop linklike" data-mode="mobile">
#       mobile
#      </li>
#      <li class="fsel mobile linklike" data-mode="regular">
#       desktop
#      </li>
#     </ul>
#    </footer>
#   </section>
#   <script type="text/javascript">
#    <!--
# var countOfTotalText = "image {count} of {total}";
# var imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"4":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"3":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};
# var maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";
# var pID = 7306204147;
# var repost_of = 7285745276;
# -->
#   </script>
#   <script>
#    try {
#                     if (
#                         !/\/\/.+\.craigslist\.org\/about\//.test(window.location.href)
#                         &&
#                         (!window.addEventListener || JSON.parse(JSON.stringify('x')) !== 'x')
#                     ) {
#                         throw "unsupported browser";
#                     }
#                 } catch (e) {
#                     function cleanup() {
#                         document.body.innerHTML = '<div id="cl-unsupported-browser" style="margin:1em;font-size:150%;text-align:center;">We have detected you are using a browser that is missing critical features.<br><br>Please visit craigslist from a modern browser.</div>';
#                         document.body.style = "display:block";
#                     }
#
#                     try {
#                         document.body.style = "display:none";
#                     } catch (e) {
#                     }
#                     window.onload = cleanup;
#                     window.clUnsupportedBrowser = true;
#                 }
#   </script>
#   <script src="//www.craigslist.org/js/general-concat.min.js?v=2d91af30d4b934fdeac883a1d566126a" type="text/javascript">
#   </script>
#   <script src="//www.craigslist.org/js/leaflet-concat.min.js?v=66cc485807e67440f6b0d8f1fbced8ae" type="text/javascript">
#   </script>
#   <script src="//www.craigslist.org/js/postings-concat.min.js?v=dc59a76497f8ac00dc99db926c8fef7a" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
latlon = soup.find('div', class_='viewposting')
lat = latlon['data-latitude']
lon = latlon['data-longitude']
print(lat, lon)
# Out:
# 34.024500 -118.156100

# %% [markdown]
# <div class="alert alert-block alert-info">
# <h3>Key Takeaways</h3>
# <ul>
#   <li>Scraping unstructured webpages involves more detective work and trial and error.</li>
#   <li>Some will have a consistent format and helpful class codes and html tags. Some won't.</li>
#   <li>Your code will need to be robust to missing fields and other inconsistencies in page formatting.</li>
#   <li>Be nice! You may need to slow the pace of your requests down.</li>
# </ul>
# </div>
